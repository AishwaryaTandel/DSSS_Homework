# %%
# !pip install line_profiler

# %%
# %load_ext line_profiler

# %%
from homework9 import res_skimage
from homework9 import approximate_pi
import numpy as np
from skimage import data, color
from skimage.transform import resize
import multiprocessing
import threading

imgs = np.uint8(data.lfw_subset()*255)
# Out:
# C:\Users\Aishwarya Tandel\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Run the profiler on the function
# %lprun -f res_skimage res_skimage(imgs)

# %%
# Data to pass to the above function
nums = [1_822_725, 22_059_421, 32_374_695,88_754_320, 97_162_66, 200_745_654]

# %%
# %%timeit

#multiprocessing
processes = []
for num in nums:
    process = multiprocessing.Process(target=approximate_pi, args = (num,))
    process.start()
    processes.append(process)
    
#wait for all processes to complete
for process in processes:
    process.join()
# Out:
# 1min 18s ± 1.42 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

#multithreading
threads=[]
for num in nums:
    thread = threading.Thread(target = approximate_pi, args = (num))
    thread.start()
    threads.append(thread)

#wait for all threads to complete
for thread in threads:
    thread.join()
# Out:
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Exception in thread Thread-12:
# Traceback (most recent call last):
#     self.run()
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 910, in run
# Exception in thread Thread-13:
#   File "C:\Users\Aishwarya Tandel\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Traceback (most recent call last):
# ...

# %%
import numpy as np
from numba import jit

@jit(nopython=True)
def approximate_pi_numba(n):
    pi_2 = 1
    nom, den = 2.0, 1.0
    for i in range(n):
        pi_2 *= nom / den
        if i % 2:
            nom += 2
        else:
            den += 2
    return 2 * pi_2

# Test the Numba-optimized function
result_numba = approximate_pi_numba(1000000)
print(result_numba)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# C:\Users\AISHWA~1\AppData\Local\Temp/ipykernel_4588/895574294.py in <module>
#       1 import numpy as np
# ----> 2 from numba import jit
#       3
#       4 @jit(nopython=True)
#       5 def approximate_pi_numba(n):
#
# ~\anaconda3\lib\site-packages\numba\__init__.py in <module>
#      41
#      42 # Re-export vectorize decorators and the thread layer querying function
# ---> 43 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      44                             get_num_threads, set_num_threads)
#      45
#
# ~\anaconda3\lib\site-packages\numba\np\ufunc\__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
# ...

# %%
# !pip3 install numba
# Out:
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\aishwarya tandel\\anaconda3\\lib\\site-packages\\numpy-1.26.2.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\aishwarya tandel\anaconda3\lib\site-packages
# ERROR: Cannot uninstall numpy 1.26.2, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps numpy==1.26.2'.
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import jit

# Original function
def approximate_pi_original(n):
    pi_2 = 1
    nom, den = 2.0, 1.0
    for i in range(n):
        pi_2 *= nom / den
        if i % 2:
            nom += 2
        else:
            den += 2
    return 2 * pi_2

# Numba-optimized function
@nb.jit(nopython=True, parallel=True)
def approximate_pi_numba(n):
    pi_2 = 1
    nom, den = 2.0, 1.0
    for i in range(n):
        pi_2 *= nom / den
        if i % 2:
            nom += 2
        else:
            den += 2
    return 2 * pi_2

# List of different values for N
nums = [10000, 20000, 30000, 40000, 50000]

# Calculate Pi for each method
results_original = [approximate_pi_original(num) for num in nums]
results_numba = [approximate_pi_numba(num) for num in nums]

# Correct value of Pi
correct_pi = np.pi

# Plot the results
plt.plot(nums, results_original, label='Original')
plt.plot(nums, results_numba, label='Numba')
plt.axhline(correct_pi, color='red', linestyle='--', label='Correct Pi')
plt.xlabel('Number of Iterations (N)')
plt.ylabel('Estimated Pi')
plt.legend()
plt.title('Estimation of Pi with Different Methods')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# C:\Users\AISHWA~1\AppData\Local\Temp/ipykernel_4588/2840810328.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from numba import jit
#       4
#       5 # Original function
#
# ~\anaconda3\lib\site-packages\numba\__init__.py in <module>
#      41
#      42 # Re-export vectorize decorators and the thread layer querying function
# ---> 43 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      44                             get_num_threads, set_num_threads)
#      45
#
# ~\anaconda3\lib\site-packages\numba\np\ufunc\__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
# ...

# %%
# !pip install numba
# Out:
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\aishwarya tandel\\anaconda3\\lib\\site-packages\\numpy-1.26.2.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\aishwarya tandel\anaconda3\lib\site-packages
# ERROR: Cannot uninstall numpy 1.26.2, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps numpy==1.26.2'.
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2

# %%
from numba import jit

@numba.jit
def approximate_pi_numba(n):
    pi_2 = 1
    nom, den = 2.0, 1.0
    for i in range(n):
        pi_2 *= nom / den
        if i % 2:
            nom += 2
        else:
            den += 2
    return 2 * pi_2
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# C:\Users\AISHWA~1\AppData\Local\Temp/ipykernel_7896/1469514365.py in <module>
# ----> 1 from numba import jit
#       2
#       3 @numba.jit
#       4 def approximate_pi_numba(n):
#       5     pi_2 = 1
#
# ~\anaconda3\lib\site-packages\numba\__init__.py in <module>
#      41
#      42 # Re-export vectorize decorators and the thread layer querying function
# ---> 43 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      44                             get_num_threads, set_num_threads)
#      45
#
# ~\anaconda3\lib\site-packages\numba\np\ufunc\__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
# ...
